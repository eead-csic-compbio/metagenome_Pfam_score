# %% [markdown]
# # Random Score

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import numpy as np
import matplotlib

# %% [markdown]
# # Maximum theoretical Score value

# %% [markdown]
# These values were obtaining using the summation of the positives Pfams entropy values

# %% [markdown]
# # MSL

# %% [markdown]
# To consider a closer range between the msl of the genomic dataset fragemented  and the msl of each metagenome,
# we take into account that the maximum of peptides of difference could be 15-20.It should be notice that if the user
# use another sizes to fragment the genomic dataset, this have to be adapted to that sizes

# %%
msl_30 = range(0,45)
msl_60 = range(45,80)
msl_100 = range(81,125)
msl_150 = range(126,175)
msl_200 = range(176,225)
msl_250 = range(226,2275)
msl_300 = range(276,300)

# %% [markdown]
# # Genomic dataset

# %%
genomic = pd.read_table('genomic_scores.features.tab', index_col=0)
genomic.columns
genomic.Feature.unique()
# Out:
# array(['Positive', 'Fe-S-un', 'PSB', 'CLSB', 'S-un ', 'GSB', 'SRB',
#        'SRB/SR', 'SR', 'SOM', 'F', 'S-isolated', 'N', 'CH4', 'OTHER',
#        'PSB ', 'SO/SR', 'S-org'], dtype=object)

# %% [markdown]
# # Score values

# %%
positive =16.018
gen_30 = 13.676
gen_60 = 16.818
gen_100 = 15.566
gen_150 = 15.848
gen_200 = 15.887
gen_250 = 16.031
gen_300 = 15.929

# %% [markdown]
# # Boxplot by metabolic capabilities

# %%
def median_sort(df):
    """Sort the columns acording to the median"""
    median_sorted = df.median().argsort()
    df_sorted = df.T.ix[median_sorted].T
    return df_sorted

# %%
feature_= genomic[['Score', 'Feature']]
features = feature_['Feature'].unique()
mydic = {}
for f in features:
    values = feature_['Score'][feature_['Feature'] == f]
    values = values.get_values()
    mydic[f] = pd.Series(values)

#f_coldic = {}
#for feat in genomic.Feature.unique():
#    tax= genomic[genomic.Feature == feat].iloc[0]['Group']
 #   f_coldic[feat] = coldic[tax]

# %%
env_feature = pd.DataFrame(mydic)
env_f_sorted = median_sort(env_feature)

# %%
fig = plt.figure(figsize=(12,6))
x = env_f_sorted.boxplot(rot=90)
#plt.xticks(size='x-small')
#plt.yticks(size='x-small')
plt.xlabel('Metabolic capability', weight='bold')
plt.ylabel('Sulfur Score (bits)', weight='bold')
plt.axhline(pergen, color='forestgreen', linewidth=1.5, ls='--')
plt.annotate( '95% percentile', (1.5, 11),)
# esta función ordena mejor los elementos en el lienzo
plt.tight_layout()

#myax = plt.gca()
#labels = myax.get_xticklabels()
#for l in labels:
 #   l.set_color(f_coldic[l.get_text()])

plt.savefig('metabolic_capabilities.png', dpi=300)

# %%
env_f_sorted
#genomic.loc[genomic['Score'].isin(11.5)]
# Out:
#        OTHER   SO/SR  S-org      SR  SRB/SR     SOM    CLSB    PSB      CH4  \
# 0     10.654  10.393  8.625  11.810  13.613  11.646  15.194  10.535  10.687
# 1     10.562   8.448  8.440  11.248  12.431  11.204  14.893     NaN     NaN
# 2     10.472   8.448    NaN  11.157  10.314  10.555  14.893     NaN     NaN
# 3     10.414   8.442    NaN  10.229  10.131  10.179  14.728     NaN     NaN
# 4     10.292   8.078    NaN  10.161   9.872   9.884  14.372     NaN     NaN
# 5     10.236   7.423    NaN  10.081   9.673   9.868  12.059     NaN     NaN
# 6     10.193   6.338    NaN   9.602   9.668   9.677  10.925     NaN     NaN
# 7     10.171     NaN    NaN   9.460   9.137   9.456  10.528     NaN     NaN
# 8     10.123     NaN    NaN   9.307   8.931   6.446  10.528     NaN     NaN
# 9     10.118     NaN    NaN   9.307   8.435     NaN  10.164     NaN     NaN
# 10    10.111     NaN    NaN   9.259   8.403     NaN   9.955     NaN     NaN
# ...

# %%
feature_ =  meta[['Sscore', 'Feature']]
features = feature_['feature'].unique()

mydic = {}
for f in features:
    values = feature_['Sscore_2017'][feature_['feature'] == f]
    values = values.get_values()
    mydic[f] = pd.Series(values)
env_feature = pd.DataFrame(mydic)
env_f_sorted = median_sort(env_feature)

fig = plt.figure(figsize=(6.8, 3.2))
x = env_f_sorted.boxplot(rot=90)
plt.xticks(size='x-small')
plt.yticks(size='x-small')
plt.xlabel('Environmental feature', weight='bold')
plt.ylabel('Sulfur Score', weight='bold')
plt.axhline(15.9, color='forestgreen', linewidth=0.5, ls='--')
plt.annotate( '95% percentile', (3, 16), fontsize='xx-small')
# esta función ordena mejor los elementos en el lienzo
plt.tight_layout()

myax = plt.gca()
labels = myax.get_xticklabels()
for l in labels:
    l.set_color(f_coldic[l.get_text()])

plt.savefig('environmental_features.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-252-2fee193ec7a1> in <module>()
# ----> 1 feature_ =  meta[['Sscore', 'Feature']]
#       2 features = feature_['feature'].unique()
#       3
#       4 mydic = {}
#       5 for f in features:
#
# NameError: name 'meta' is not defined

# %%
x = ambientes_sorted.boxplot(rot=90)

plt.xlabel('Enviromental package', weight='bold')
plt.ylabel('Sulfur Score', weight='bold')

myax = plt.gca()
labels = myax.get_xticklabels()
for l in labels:
    l.set_color(coldic[l.get_text()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Subgroup'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#f_coldic = {}

#for feat in genomic.Subgroup.unique():
 #   env_p = genomic[genomic.Feature == feat].iloc[0]['Feature']
#   f_coldic[feat] = coldic[env_p]

# %%
env_feature = pd.DataFrame(mydic)

# %%
env_f_sorted = median_sort(env_feature)

fig = plt.figure(figsize=(12, 6))
x = env_f_sorted.boxplot(rot=90)
plt.xticks(size='x-small')
plt.yticks(size='x-small')
plt.xlabel('Environmental feature', weight='bold')
plt.ylabel('Sulfur Score', weight='bold')
plt.axhline(15.9, color='forestgreen', linewidth=0.5, ls='--')
plt.annotate( '95% percentile', (3, 16), fontsize='small')
# esta función ordena mejor los elementos en el lienzo
plt.tight_layout()

myax = plt.gca()
labels = myax.get_xticklabels()
for l in labels:
    l.set_color(f_coldic[l.get_text()])

#plt.savefig('environmental_features.png', dpi=300)

# %%
#Read and parse results 


size60 = pd.read_table('pfam_fixed.size60.tab.parse.tab.header.tab')
size100 = pd.read_table('pfam_fixed.size100.tab.parse.tab.header.tab')
size150 = pd.read_table('pfam_fixed.size150.tab.parse.tab.header.tab')
size200 = pd.read_table('pfam_fixed.size200.tab.parse.tab.header.tab')
size250 = pd.read_table('pfam_fixed.size250.tab.parse.tab.header.tab')
size300 = pd.read_table('pfam_fixed.size300.tab.parse.tab.header.tab')
#Convert to dataframes using pivot tables 
piv_60 = pd.pivot_table(size60,index=["id"], columns=["replicate"], values=["value"])
piv_100 = pd.pivot_table(size100,index=["id"], columns=["replicate"], values=["value"])
piv_150 = pd.pivot_table(size150,index=["id"], columns=["replicate"], values=["value"])
piv_200 = pd.pivot_table(size200,index=["id"], columns=["replicate"], values=["value"])
piv_250 = pd.pivot_table(size250,index=["id"], columns=["replicate"], values=["value"])
piv_300 = pd.pivot_table(size300,index=["id"], columns=["replicate"], values=["value"])
# Out:
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
size150.head()
# Out:
#           id  replicate           pfam  value
# 0  4440966.3       1000   Pfam entropy  4.494
# 1  4440966.3        100   Pfam entropy  6.572
# 2  4440966.3        101   Pfam entropy  5.369
# 3  4440966.3        102   Pfam entropy  4.956
# 4  4440966.3        103   Pfam entropy  4.004

# %%
#Maximum values 
s30 = 13.676 
s60 = 16.818
s100 = 15.566
s150 = 15.848
s200 = 15.587
s250 = 16.031
s300 = 15.299
#Percentiles 
np.percentile(piv_60,95)
# Out:
# 9.8670000000000009

# %%
piv_60.T.boxplot()

# %%
def median_sort(df):
    """Sort the columns acording to the median"""
    median_sorted = df.median().argsort()
    df_sorted = df.T.ix[median_sorted].T
    return df_sorted

# %% [markdown]
# # Creating boxplot random scores size 60

# %%
plt.figure(figsize=(12,6))
size60_sorted = median_sort(piv_60.T)
#x = size60_sorted.boxplot(rot=90,)
size60_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s60, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(np.percentile(piv_60,95), color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (2,17), fontsize='small')
plt.annotate( '95 percentile', (2,10), fontsize='small')
plt.title("SS in met of MSL 60 computed 1000X using 53% of random Pfams", weight='bold')
#plt.savefig("random_60_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')

# %%
plt.figure(figsize=(12,6))
size100_sorted = median_sort(piv_100.T)
size100_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s100, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(np.percentile(piv_100,95), color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (2,15.7), fontsize='small')
plt.annotate( '95 percentile', (2,9.8), fontsize='small')
plt.title("SS in met of MSL 100 computed 1000X using 51% of random Pfams", weight='bold')
plt.savefig("random_100_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')
# Out:
# /usr/local/lib/python3.4/dist-packages/numpy/lib/function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)

# %%
plt.figure(figsize=(12,6))
size150_sorted = median_sort(size150)
#x = size60_sorted.boxplot(rot=90,)
size150_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s150, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(percen95_150, color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (2,15.7), fontsize='small')
plt.annotate( '95 percentile', (2,8.5), fontsize='small')
plt.title("SS in met of MSL 150 computed 1000X using 50% of random Pfams", weight='bold')
plt.savefig("random_150_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')

# %%
plt.figure(figsize=(12,6))
size200_sorted = median_sort(size150)
#x = size60_sorted.boxplot(rot=90,)
size200_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s200, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(percen95_200, color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (2,15.7), fontsize='small')
plt.annotate( '95 percentile', (2,8.5), fontsize='small')
plt.title("SS in met of MSL 200 computed 1000X using 50% of random Pfams", weight='bold')
plt.savefig("random_200_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')

# %%
plt.figure(figsize=(12,6))
size250_sorted = median_sort(size150)
size250_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s250, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(percen95_250, color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (2,16.2), fontsize='small')
plt.annotate( '95 percentile', (2,8.5), fontsize='small')
plt.title("SS in met of MSL 250 computed 1000X using 50% of random Pfams", weight='bold')
plt.savefig("random_250_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')

# %%
plt.figure(figsize=(12,6))
size300_sorted = median_sort(size300)
size300_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s300, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(percen95_300, color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (0.7,15.4), fontsize='small')
plt.annotate( '95 percentile', (0.7,9), fontsize='small')
plt.title("SS in met of MSL 250 computed 1000X using 50% of random Pfams", weight='bold')
plt.savefig("random_300_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')

# %%
plt.figure(figsize=(12,6))
size250_sorted = median_sort(size150)
size250_sorted.boxplot(grid=True, rot=90, whis=[5,95]  )
plt.xticks(size='xx-small')
plt.ylabel('Sulfur Score', weight='bold')
plt.xlabel('Metagenomes', weight='bold')
plt.axhline(s250, color='forestgreen', linewidth=1.3, ls='--')
plt.axhline(percen95_250, color='blue', linewidth=1.3, ls='--')
plt.annotate( 'Maximum theoretical value', (2,16.2), fontsize='small')
plt.annotate( '95 percentile', (2,8.5), fontsize='small')
plt.title("SS in met of MSL 250 computed 1000X using 50% of random Pfams", weight='bold')
plt.savefig("random_250_pfams.png", dpi=300)
#plt.t title("in metagenomes of MSL 60", weight='bold')

# %%
size300.T.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3c24adeeb8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3c1bcdd550>]], dtype=object)

# %% [markdown]
# # Top Scores metagenomes several inputs

# %%
#Theorical maximumm values 
#30 => 4548350.3. =>13.676



s30 = 13.676 
s60 = 16.818
s100 = 15.566
s150 = 15.848
s200 = 15.587
s250 = 16.031
s300 = 15.299

# %%
size30_inputs=pd.read_table('size30.inputs.tab', index_col=0)
size60_inputs=pd.read_table('size60.inputs.tab', index_col=0)
size100_inputs=pd.read_table('size100.inputs.tab', index_col=0)
size150_inputs=pd.read_table('size150.inputs.tab', index_col=0)
size200_inputs=pd.read_table('size200.inputs.tab', index_col=0)
size250_inputs=pd.read_table('size250.inputs.tab', index_col=0)
size300_inputs=pd.read_table('size300.inputs.tab', index_col=0)

# %% [markdown]
# # Size 30

# %%
size30_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s60, color='forestgreen', linewidth=1.3, ls='--')
plt.axvline(13.676, color='blue', linewidth=1.3, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (17, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (13.2, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 30", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl30.png', dpi=300)

# %% [markdown]
# # Size 60

# %%
size60_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s60, color='forestgreen', linewidth=1.3, ls='--')
plt.axvline(16.488, color='blue', linewidth=1.3, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (17, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (16, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 60", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl60.png', dpi=300)

# %% [markdown]
# # Size 100

# %%
size100_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s100, color='forestgreen', linewidth=0.5, ls='--')
plt.axvline(15.564, color='blue', linewidth=1.3, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (15.8, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (15, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 100", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl_100.png', dpi=300)

# %% [markdown]
# # Size 150

# %%
size150_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s150, color='forestgreen', linewidth=0.5, ls='--')
plt.axvline(15.763, color='blue', linewidth=0.5, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (15.8, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (15.3, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 150", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl_150.png', dpi=300)

# %% [markdown]
# # Size 200

# %%
size200_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s150, color='forestgreen', linewidth=0.5, ls='--')
plt.axvline(15.652, color='blue', linewidth=0.5, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (15.8, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (15.3, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 200", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl_200.png', dpi=300)

# %% [markdown]
# # Size 250

# %%
size200_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s150, color='forestgreen', linewidth=0.5, ls='--')
plt.axvline(15.712, color='blue', linewidth=0.5, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (15.8, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (15.3, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 250", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl_250.png', dpi=300)

# %% [markdown]
# # Size 300

# %%
size300_inputs.T.boxplot(grid=True, vert=False, whis=[5,95] )
plt.axvline(s150, color='forestgreen', linewidth=0.5, ls='--')
plt.axvline(13.891, color='blue', linewidth=0.5, ls='--') 
plt.axhline(4, color='orange', linewidth=0.5, ls='--')
plt.annotate( 'T', (15.5, 2), fontsize='small', fontweight='bold')
plt.annotate( 'R', (13.5, 2), fontsize='small', fontweight='bold')
plt.title("Maximum score size 60", fontweight='bold',fontsize='large' )
    #plt.yticks(size='xx-small')
    #plt.xlabel('Entropy (bits)')
plt.ylabel('Pfam percent used to compute the SS' )
plt.xlabel('Sulfur Score (bits)')
plt.savefig('test_random_msl_300.png', dpi=300)

# %%
# genomic random

# %%
random_gen = pd.read_table('genomic_random.tab')
#random_gen_piv = pd.pivot_table(random_gen,index=["genome"], columns=["replicate"], values=["score"])
random_gen.columns()
# Out:
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-ba7372e38be7> in <module>()
#       1 random_gen = pd.read_table('genomic_random.tab')
#       2 #random_gen_piv = pd.pivot_table(random_gen,index=["genome"], columns=["replicate"], values=["score"])
# ----> 3 random_gen.columns()
#
# TypeError: 'Index' object is not callable

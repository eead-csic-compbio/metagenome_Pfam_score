# %%
#Import libraries
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import numpy as np

import matplotlib
sns.set_style("darkgrid")

# %%
df=pd.read_table("completenes",index_col=0)
df_met=pd.read_table("metagenomes.completeness.tab", index_col=0)

# %%
df.mean()
# Out:
# Thiobacillus (11.61)       67.146429
# Allochromatium (10.797)    68.821429
# Ammonifex (12.508)         48.775000
# Desulfovibrio (11.442)     56.121429
# Hyphomicrobium (3.236)     68.392857
# Methanosarcina (5.93)      58.171429
# Microccocus (-3.588)       58.846429
# Pelodictyon (11.836)       61.660714
# Ruegeria (2.707)           77.282143
# Synechococcus (3.704)      53.485714
# Enterococcus (-0.194)      41.050000
# Sulfolobus (5.457)         51.428571
# Sulfolobus (5.457).1       51.428571
# dtype: float64

# %%
df.median()
# Out:
# Thiobacillus (11.61)       72.05
# Allochromatium (10.797)    72.05
# Ammonifex (12.508)         50.00
# Desulfovibrio (11.442)     57.10
# Hyphomicrobium (3.236)     65.85
# Methanosarcina (5.93)      59.15
# Microccocus (-3.588)       57.10
# Pelodictyon (11.836)       60.00
# Ruegeria (2.707)           83.75
# Synechococcus (3.704)      51.45
# Enterococcus (-0.194)      28.60
# Sulfolobus (5.457)         51.45
# dtype: float64

# %%
df_met.mean()
# Out:
# 4510168.3 (7.781)     89.060714
# 4451035.3 (9.918)     83.792857
# 4461840.3 (8.813)     85.196429
# 4441102.3 (9.986)     73.025000
# 4493725.3 (9.547)     87.535714
# 4441599.3 (9.274)     84.417857
# 4441663.3 (9.986)     73.025000
# 4525341.3 (9.287)     83.442857
# 4489656.3 (-2.649)    54.278571
# 4440320.3 (0.1)       15.242857
# 4489328.38 (4.958)    78.117857
# 4478222.3 (4.88)      79.725000
# dtype: float64

# %%
df.head()
# Out:
#                             Thiobacillus (11.61)  Allochromatium (10.797)  \
# Sulfite oxidation_1                         88.9                     77.8
# Thiosulfate oxidation_2                     60.0                     60.0
# Tetrathionate oxidation_3                  100.0                    100.0
# Tetrathionate reduction_4                   76.5                     76.5
# Sulfate reduction DS_5                      75.0                     70.0
#
#                             Ammonifex (12.508)  Desulfovibrio (11.442)   \
# Sulfite oxidation_1                       77.8                     66.7
# Thiosulfate oxidation_2                    0.0                     30.0
# Tetrathionate oxidation_3                  0.0                      0.0
# Tetrathionate reduction_4                 76.5                     76.5
# Sulfate reduction DS_5                    75.0                     75.0
#
#                             Hyphomicrobium (3.236)  Methanosarcina (5.93)  \
# ...

# %%
df_met.head()
# Out:
#                           4510168.3 (7.781)  4451035.3 (9.918)  \
# Sulfite oxidation                     100.0              100.0
# Thiosulfate oxidation                  80.0               70.0
# Tetrathionate oxidation               100.0              100.0
# Tetrathionate reduction                76.5               76.5
# Sulfate reduction DS                   75.0               75.0
#
#                           4461840.3 (8.813)  4441102.3 (9.986)  \
# Sulfite oxidation                     100.0              100.0
# Thiosulfate oxidation                  80.0               60.0
# Tetrathionate oxidation               100.0              100.0
# Tetrathionate reduction                76.5               76.5
# Sulfate reduction DS                   75.0               70.0
#
#                           4493725.3 (9.547)  4441599.3 (9.274)  \
# Sulfite oxidation                     100.0              100.0
# Thiosulfate oxidation                  70.0               70.0
# ...

# %%
axs = sns.clustermap(df)
sand = plt.setp(axs.ax_heatmap.get_xticklabels(), rotation=90)
plt.savefig("/home/val/Dropbox/paper_azufre/resubmission/GigaScience/Figures/comp_genomes.png",bbox_inches='tight', dpi=500)

# %%
axs = sns.clustermap(df_met)
sand = plt.setp(axs.ax_heatmap.get_xticklabels(), rotation=90)
#plt.tight_layout()
plt.savefig("/home/val/Dropbox/paper_azufre/resubmission/Figures/comp_metSS.png",bbox_inches='tight', dpi=500)

# %% [markdown]
# # Correlaciones

# %%
corr_paths_met=df_met.corr(method='pearson')
axs = sns.clustermap(corr_paths_met)
sand = plt.setp(axs.ax_heatmap.get_yticklabels(), rotation=0)
plt.savefig("/home/val/Dropbox/paper_azufre/resubmission/Figures/comp_met_corr.png",bbox_inches='tight', dpi=500)

# %%
corr_paths=df.corr()
axs = sns.clustermap(corr_paths)
sand = plt.setp(axs.ax_heatmap.get_yticklabels(), rotation=0)
plt.savefig("/home/val/Dropbox/paper_azufre/resubmission/Figures/comp_gen_corr.png",bbox_inches='tight', dpi=500)

# %%
# Out:
# Text(0.5,0,'Percent of completness ')

# %%
def median_sort(df):
    """Sort the columns acording to the median"""
    median_sorted = df.median().argsort()
    df_sorted = df.T.ix[median_sorted].T
    return df_sorted

# %%
sns.boxplot(orient="h", data=sorted_df, linewidth=0.5)
plt.xlabel('Percent of completness ', weight='bold', size='large')
#plt.savefig('Fig5C.png', dpi=400)
# Out:
# Text(0.5,0,'Percent of completness ')

# %%
sns.boxplot(orient="h", data=median_sort(df_met), linewidth=0.5)
plt.xlabel('Percent of completness ', weight='bold', size='large')
#plt.savefig('Fig5C.png', dpi=400)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# Text(0.5,0,'Percent of completness ')
